# %% [markdown]
# # Initial Text Processing
# The purpose of this notebook is to conduct initial text pre-processing of the text columns of the data from Hitter_Data_Cleaning.ipynb.

# %% [markdown]
# ## Setup/Initiation:

# %% [markdown]
# First, importing needed packages:

# %%
import pickle
import pandas as pd
import matplotlib.pyplot as plt
from pylab import rcParams
# %matplotlib inline
rcParams['figure.figsize'] = 20,10
import numpy as np
import glob
from scipy import stats
from bs4 import BeautifulSoup
import requests
import re
from IPython.core.display import display, HTML # make sure Jupyter knows to display it as HTML

# %% [markdown]
# Bringing in the pickled data:

# %%
pwd
# Out:
# '/Users/patrickbovard/Documents/GitHub/MLB-Scouting-Reports-Analysis'

# %%
with open('./Data_Files/cleaned_hitter_data.pickle', 'rb') as read_file:
    cleaned_hitter_data = pickle.load(read_file)

# %%
cleaned_hitter_data.head()
# Out:
#             Name                                    Physical_Health  \
# 0      CJ Abrams  A pure athlete with quick twitch muscles, very...
# 1  Osvaldo Abreu  Smaller frame with a little room to add streng...
# 2  Osvaldo Abreu  Small frame; toned body with muscular definiti...
# 3   Ronald Acuna  Quick-twitch movement, explosive hands; presen...
# 4   Ronald Acuna  Impressive, proportioned athlete with plus str...
#
#   Risk_Factor                                         Hit_Report  \
# 0     Extreme  Very raw as a hitter with a lot of mechanical ...
# 1    Moderate  Open stance, steady at the plate, hands are ti...
# 2        High  Above-average bat speed; noisy hands; minor hi...
# 3        High  High hands stay quiet through load, attacks ba...
# 4         Low  High hands (above ear) in set-up. Moderate leg...
#
#                                         Power_Report  \
# 0  Beyond needing to gain strength to add to his ...
# 1  Frame translates to below-average raw power, l...
# ...
